# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>Домашнее задание 1.2</h1>
# </div>

# %% [markdown]
# 👩‍🎓👨‍🎓 В этой домашке мы пошагово решим мини-кейс для отдела B2B. Но перед этим давай набьем руку в работе со словарями.

# %% [markdown]
# ### Подготовительное задание – практикум по словарям
#
# *Перед тем, как начать работу над кейсом, потренируемся в использовании словарей. Это поможет тебе при решении кейса.*
#
# 1. Создай пустой словарь `dict_emails`
# 2. Добавь туда ключ `gmail` со значением `andrei@gmail.com`
# 3. Добавь по ключу `gmail` также элементы `viktoria@gmail.com` и `ella@gmail.com`, чтобы в значении оказались все три почты. Для этого используй список.
# 4. Выведи каждый e-mail из словаря в новой строчке с помощью цикла `for`.
# *Если сомневаешься, как выполнить последний пункт, смело смотри шпаргалку (раздел "Перебор ключей и значений в словаре в цикле for")*

# %%
# 1
dict_emails = dict()

# 2
dict_emails['gmail'] = 'andrei@gmail.com'
# print(dict_emails)

# 3
dict_emails['gmail'] = ['andrei@gmail.com', 'viktoria@gmail.com' , 'ella@gmail.com' ]  

# 4

for i in dict_emails.values():
    print(i)
# Out:
# ['andrei@gmail.com', 'viktoria@gmail.com', 'ella@gmail.com']

# %% [markdown]
# *Осталась последняя мини-тренировка , чтобы совсем уверенно чувствовать себя со словарями.*
#
# 5. Добавь в словарь ключ `yandex` со значением `liza@yandex.ru`
# 6. Из словаря `dict_emails` по ключу `yandex` вытащи значение.

# %%
# 5
dict_emails['yandex'] = 'liza@yandex.ru'

# 6
print(dict_emails['yandex'])
# Out:
# liza@yandex.ru

# %% [markdown]
# ### Изучим кейс
#
# 👩‍💻 Вероятно,  редкие доменные имена в почтах наших клиентов — это корпоративные адреса. Если в нашей базе много емейлов с корпоративными доменами, мы сможем использовать эти данные в B2B-продажах. 🤔 Ведь это означает, что офисные работники заинтересованы в обучении в Skyeng, и компании смогут сделать партнерку со Skyeng частью своей программы лояльности для сотрудников.
#
# Твоя задача: извлечь из клиентской базы домены почтовых адресов и посчитать их, а отдел B2B-продаж проанализирует редкие домены и подготовит коммерческие предложения для компаний, где работают эти клиенты.
#
# На пути выполнения этой задачи потренируйся подготавливать и исследовать сырые данные, потому что, как ты наверняка знаешь, 80% работы аналитика проходит именно в подготовке данных.

# %%
from crm_module import crm_in_list as crm # подключимся к данным, запустив ячейку с помощью shift+enter

# %% [markdown]
# ### Задание 1
# Для начала давай изучим данные: какого они типа, какие элементы внутри. Изучи код ниже и напиши код, который выведет второй элемент первого элемента объекта `crm` и его тип.

# %%
crm[0:10] # посмотрим на данные
# Out:
# [[510266, 'b0198ff4@mail.ru'],
#  [882968, '5bda448e2@mail.ru'],
#  [1446917, 'e860d3c@yandex.ru'],
#  [237601, '17f1f367@mail.ru'],
#  [79304, 'f408b395d@gmail.com'],
#  [535956, '15fcf41fe@i-free.com'],
#  [1657538, 'e13cbd939@mail.ru'],
#  [43966, 'd4e8b4@mail.ru'],
#  [2112521, '1763b7@mail.ru'],
#  [1038965, '21b786@mail.ru']]

# %%
print((crm[0]), (type(crm[0]))) # смотрим, что лежит в первом элементе
# Out:
# [510266, 'b0198ff4@mail.ru'] <class 'list'>

# %%
print((crm[0][0]), type(crm[0][0])) # смотрим, что лежит в первом элементе первого элемента
# Out:
# 510266 <class 'int'>

# %%
print(crm[0][1], type(crm[0][1])) # напиши код, который выведет второй элемент первого элемента объекта crm и его тип
# Out:
# b0198ff4@mail.ru <class 'str'>

# %% [markdown]
# ### Задание 2
#
# Теперь давай достанем из выгрузки список почт наших клиентов. Используя обращения по индексу и метод `.append`, это можно сделать в несколько строк. Дополни код ниже.
# 1. Используй цикл `for in` для перебора элементов списка
# 2. По индексу получи нужный элемент списка
# 3. Метод `.append()` наполнит новый список нужными значениями

# %%
# Hint: из предыдущего задания ты уже знаешь, в каком элементе списка хранится почта

# создадим пустой список, куда будем складывать почты отдельно от остальных данных 
only_mail = list() 

for data in crm: 
  # напиши здесь свой код
    only_mail.append(data[1])
only_mail[0:8]
# Out:
# ['b0198ff4@mail.ru',
#  '5bda448e2@mail.ru',
#  'e860d3c@yandex.ru',
#  '17f1f367@mail.ru',
#  'f408b395d@gmail.com',
#  '15fcf41fe@i-free.com',
#  'e13cbd939@mail.ru',
#  'd4e8b4@mail.ru']

# %% [markdown]
# ### Задание 3
#
# Теперь создай новый список, в котором будут только домены почт после символа `«@»`. Обязательно назови этот список `domains`
#
# Тебе помогут строковые методы и метод `.append()`. Эта задача аналогична получению почты из строки — логика решения будет точно такая же. Как всегда, способов решить эту задачу несколько — выбирай тот, что тебе ближе.

# %%
# Hint: не забудь начать с пустого списка под названием domains, где окажутся только домены
domains = list()

for domain in only_mail:
    domains.append(domain[domain.find('@') + 1:])
domains[0:8]
# Out:
# ['mail.ru',
#  'mail.ru',
#  'yandex.ru',
#  'mail.ru',
#  'gmail.com',
#  'i-free.com',
#  'mail.ru',
#  'mail.ru']

# %% [markdown]
# ### Задание 4
#
# Создадим копию наших доменов так, чтобы исходные данные не затерлись, а затем удалим все домены `skyeng.ru`.
#
# 1. Ниже уже есть код, который копирует список, чтобы все операции, которые ты будешь проводить, не коснулись исходного списка и всегда можно было бы к нему обратиться.
#
# 2. Используй цикл `while` для обработки каждого элемента списка
#
# 3. Используй метод `remove()` для удаления лишних элементов
#
# ❗️ Ниже использован новый метод работы со списками — `copy()`. Он создает копию списка, а не просто ссылается на исходный, как происходит при присваивании через оператор `=`. Ниже продемонстрирован синтаксис, а детали можно почитать в шпаргалке.
#
# 🧩 Там же, в шпаргалке, есть и полезное дополнение о конструкциях операторов в циклах. Сделать задание можно как способом, что мы рассматривали на занятии, так и новым из шпаргалки.

# %%
copy_domains_number4 = domains.copy() # копируем список доменов из задания 3, чтобы последующие изменения не коснулись исходного списка. Этот код будет работать правильно, только если в задании 3 список доменок был назван domains

# Hint: помни, что метод remove() удаляет лишь первое вхождение.
while 'skyeng.ru' in copy_domains_number4:
    copy_domains_number4.remove('skyeng.ru')
copy_domains_number4[0:8]
# Out:
# ['mail.ru',
#  'mail.ru',
#  'yandex.ru',
#  'mail.ru',
#  'gmail.com',
#  'i-free.com',
#  'mail.ru',
#  'mail.ru']

# %% [markdown]
# ### Задание 5
# В Skyeng также есть международный отдел – и почты его сотрудников имеют домен `skyeng.com`. Теперь напиши код, который будет удалять и почты с доментом `skyeng.ru`, и почты с доменом `skyeng.com`. Для проверки скопируем исходный список еще раз.

# %%
copy_domains_number5 = domains.copy() # скопируем список доменов из задания 3 еще раз, чтобы убедиться, что наш код удаляет почты двоих домена

# напиши свой код тут
for i in copy_domains_number5:
    if i == 'skyeng.ru':
        copy_domains_number5.remove(i)
    if i == 'skyeng.com':
        copy_domains_number5.remove(i)
copy_domains_number5[0:8]
# Out:
# ['mail.ru',
#  'mail.ru',
#  'yandex.ru',
#  'mail.ru',
#  'gmail.com',
#  'i-free.com',
#  'mail.ru',
#  'mail.ru']

# %% [markdown]
# ### Задание 6
#
# Создай список с уникальными доменами.
#
# Как обычно, можно решить эту задачу несколькими способами. Вот 2 возможных варианта.
#
# 1. Ты можешь использовать более лаконичное решение – через множество. Если затрудняешься в решении через множество, обязательно посмотри шпаргалку.
#
# 2. Также можно наполнить новый список с помощью метода `.pop()`, о котором мы говорили на занятии. Такое решение более заковыристое, но хорошо тренирует продумывание логики кода.

# %%
# Hint для решения через pop(): если ты инициализируешь словарь/список/множество, приравнивая его к другому, новый объект будет ссылаться на тот же участок памяти, что и старый. Но есть метод, который позволяет копировать объект, не ссылаясь на него.

unic_domain = list()
# напиши здесь свой код

unic_domain = set(domains)
print('количество уникальных записей: ', len(unic_domain))
print(unic_domain)
# Out:
# количество уникальных записей:  1832
# {'live.com', 'aeroclub.ru', 'heineken.com', 'ru.storck.com', 'sberbank.ru', 'sladis.ru', 'sistersmodels.ru', 'may.ru', 'inbox.ry', 'nwytg.com', 'gmail.cim', 'evgeniya-cherkasova.ru', 'mayl.ru', 'globus.ru', 'mail.con', 'maiinator.com', 'emotorwerks.com', 'mama.ru', '2gis.ru', 'mediskin.rut', 'tele2.ru', 'part-iskra.org', 'globo.com', 'mail.r', 'nxt.ru', 'ua.ru', 'edfg.tf', 'ru.nestle.com', 'moldtelecom.md', 'kb.ru', 'paradise-star.com', 'abp.am', 'payu.ru', 'icoud.com', 'testovaya.ru', 'ydbdbd.ru', 'dasglobal.ru', 'umail.uz', 'svetal.ru', 'gazprombank.ru', 'yandex.ru11', 'vafina.com', 'rucontent.ru', 'wp.pl', 'yugs.ru', 'wef.wef', 'egat.co.th', 'ssscredit.ru', 'caprice-wostok.ru', 'sent.com', 'outluk.ru', 'gnail.com', 'nestle.com', 'ves-media.com', 'integrotechnologies.ru', 'oboz.com.ua', 'toyota-motor.ru', 'gmel.com', 'wikrgroup.com', 'issnet.ru', 'megafon.ru', 'egeg.ru', 'ss.ru', 'bc.ru', 'gmaol.com', 'arbtr.legal', 'tdhlvz.ru', 'ovbport.ru', 'protomail.com', 'ottoruss.ru', 'airastana.com', 'kimep.kz', 'hormail.com', 'mail.ru.il', 'kama-crystal.com', 'gmaila.com', '3003mail.ru', 'fireart-d.com', 'nsl.cz', 'azurgames.com', 'grundfos.com', 'ronacher.eu', 'askonalife.ru', 'supastar.ru', 'siemens.com', 'qq.hs', 'utsrussia.ru', 'rj-games.com', 'bayaderagroup.com', 'ctb.ru', 'metalline.ru', 'niiegp.ru', 'yoola.com', 'kraftmilk.com', 'unilever.com', 'walla.co.il', 'runex.ru', 'mail.eu', 'shm.ru', 'hotmail.de', 'mail.bg', 'tdaero.ru', 'dmitrov.me', 'cloud.com', 'ail.com', 'athens.kiev.ua', 'difff.ru', 'dddd.com', 'lafargeholcim.com', 'gmail.ru', '2aevent.ru', 'tolyattinec.ru', 'vpleg.pro', 'ab-bpa.ru', 'wemakefab.ru', 'bk.ru1', 'eqvanta.com12', 'nm.ru', 'gmacl.com', 'edu.tatar.ru', 'samtakoy.ru', 'gmail.con', 'fadente.es', 'guerillamail.com', 'egis.ru', 'crm.st', 'valua.ry', 'grgrq.la', 'conti.de', 'sakarya.edu.tr', 'mail.ru11', 'qq.ym', 'mts.by', 'mezenev.com', 'mskh.am', 'ddd.ru', 'socar-aqs.com', 'qw.gl', '777gmail.com', 'medianation.ru', 'mailinator.ru', 'pma.su', 'e1.ru', 'appodeal.com', 'soloviev.me', 'metok.ru', 'patriciagarciadeparedes.es', 'g5e.com', 'tes2324t.ru', 'norbit.ru', 'mil.ru', 'iqoption.com', 'phoenix-llc.ru', 'test.tests', 'upr.mnsk.rw.by', 'start.skyeng.ru', 'tochka.com', 'hot.ee', 'irisdigital.ru', 'konstanti.ru', 'my.com', 'kolomeetz.ru', 'mikhaileliseev.com', 'open.ru', 'axa.es', 'sampo.ru', 'bi.zone', 'peleman.com', 'yomail.info', 'mhshop.ru', 'veb-leasing.ru', 'vtbforex.ru', 'vseinstrumenti.ru', 'worldskills.ru', 'yandex.ua', 'mbnrs.ru', 'slyeng.ru', 'hurtlocker.pro', 'iprospect.ru', 'iist.ru', 'maillink.live', 'inn.ru', 'artlu.ru', 'studentivan.ru', 'globalprinting.ru', 'resenergo.ru', 'gmal.com', 'bataev.ru', 'gmx.at', 'molodost.bz', 'mail15.com', 'goal.ru', 'orlime.ru', 'retal.ru', 'osttpm.ru', 'daetopravda.ru', 'ru.inditex.com', 'yandex.r', 'eriell.com', 'gmqil.com', 'modulbank.ru', 'allianz.ru', 'grafitus.lt', 'ridzel.ru', 'sjfdhjskdf.ru', 'skyway.kz', 'yabloki19.ru', 'gmail.c', 'kraftheinz.com', 'ann.ru', 'malinator.com', 'omc.ru', 'ikea.com', 'lust.ru', 'wargaming.net', 'pr3.eu', 'mmm.ru', 'profi.travel', 'fere.ru', 'school1387.ru', 'umail365.com', 'fleetcor.ru', 'takeda.com', 'avallac.ru', 'abtassoc.com', 'cosmostone.ru', 'poltank.com', 'school1465.ru', 'hoya-lens.ru', '156.com', 'boardriders.com', 'qq.gh', 'proya.pro', 'korp.mail.ru', 'nspk.ru', 'rikorgames.com', 'baltika.com', 'renault.com', 'servier.com', 'peri.ru', 'kinzerskiy.clinic', 'alloka.ru', 'radiodacha.ru', 'jkdfhgkjfdg.gg', 'i.ua', 'urfu.me', 'mobiogroup.com', 'gou515.spb.ru', 'vingrad.ru', 'yakushev.eu', 'emex.ru', 'gilsinp.ru', 'inboz.ru', 'strauss-group.ru', 'enazadev.ru', 'kazatomprom.kz', 'gmail.kom', 'gmil.som', 'secondcompany.nlsymbat', 'just-for.com', 'change.uz', 'zvet.ru', 'list.com', 'rambler.ry', 'gmajl.com', 'yundex.ru', 'qiwi.tech', 'dfuhg.fu', 'eandex.ru', 'gma.c', 'panika.org', 'hotmail.gr1', '1c.com', 'dd.dd', 'gmaildod.com', 'chelcom.ru', 'kambalov.ru', 'meat.comp.ru', 'dgg1hh.ru', 'mosidea.ru', 'tut.bu', 'ferronordic ...

# %%
# Решение через pop():

unic_domain = list()
# напиши здесь свой код

copy_domains_number6 = domains.copy()
for i in copy_domains_number6:
    if i not in unic_domain:
        unic_domain = copy_domains_number6.pop()
unic_domain
# Out:
# 'gmail.com'

# %% [markdown]
# ### Задание 7
#
# Посчитай количество вхождений каждого домена. Здесь стоит использовать код, который написан в прошлых заданиях, а также воспользоваться структурой словарь. Подумай, что должно быть ключом, а что – значением.
#
# 1. Создай словарь
#
# 2. Напиши цикл, который будет считать количество вхождений каждого домена

# %%
# Hint: количество вхождений элемента в список можно посчитать методом count()
count_unic_domain = dict()

for i in domains:
    count_unic_domain[i] = domains.count(i)
count_unic_domain
# Out:
# {'mail.ru': 16367,
#  'yandex.ru': 6245,
#  'gmail.com': 17715,
#  'i-free.com': 1,
#  'icloud.com': 743,
#  'tandem.ru': 1,
#  'inbox.ru': 855,
#  'ukr.net': 210,
#  'yum.com': 3,
#  'bk.ru': 1530,
#  'qq.com': 4,
#  'inbox.lv': 97,
#  'yandex.com': 36,
#  'veeam.com': 1,
#  'list.ru': 899,
#  'yahoo.com': 239,
#  'ya.ru': 354,
#  'mail.com': 123,
#  'rambler.ru': 777,
#  'ex.ru': 1,
#  'atomrus.ru': 4,
#  'mai.ru': 20,
#  'rngoil.ru': 1,
#  'qw.km': 1,
#  'gmail.coom': 1,
#  'hotmail.com': 217,
#  'ibox.ru': 1,
#  'egat.co.th': 1,
#  'kinross.com': 14,
#  'gmail.com1': 22,
#  'mail.ry': 11,
#  'upr.mnsk.rw.by': 1,
#  'bigbadaboom.com': 231,
#  'vayner.ru': 1,
#  'manychat.com': 1,
#  'krastsvetmet.ru': 10,
#  'index.ru': 1,
#  'gmail.ru': 167,
#  'seznam.cz': 8,
#  'gamail.com': 8,
#  'croc.ru': 7,
#  'fircroft.com': 1,
#  'asd.it': 1,
#  'outlook.com': 63,
#  'provectus.com': 2,
#  'i.ua': 40,
#  'tut.by': 37,
#  'hilti.com': 7,
#  'yandex.ry': 4,
#  'ramler.ru': 1,
#  'rb.com': 3,
#  'bnpparibas.com': 1,
#  'wweb.kz': 1,
#  'pr3.eu': 1,
#  'nm.ru': 5,
#  '12storeez.com': 1,
#  'decathlon.com': 15,
#  'msn.com': 3,
#  'a-sign.ru': 1,
#  'gmail.con': 24,
#  'e1.ru': 6,
#  'usa.com': 1,
#  'hettich.ru': 1,
#  'playtika.com': 1,
#  'example.com': 16,
#  'ik-mercury.ru': 1,
#  'qq.sl': 1,
#  'qmail.com': 9,
#  '2107school.ru': 1,
#  'yamed.ru': 1,
#  'picksell.ru': 1,
#  'cloud.ru': 1,
#  'sbcglobal.net': 3,
#  'ss.ru': 1,
#  'test.email7': 1,
#  'a.bc': 1,
#  'dl-trans.ru': 1,
#  'yandex-team.ru': 12,
#  'euroml.ru': 1,
#  'lift.ru': 3,
#  'divisadero.es': 2,
#  'puig.com': 1,
#  'autodata.ru': 1,
#  'furgon-mk.ru': 1,
#  'kambalov.ru': 1,
#  'outlook.es': 4,
#  'akdn.org': 1,
#  'truckerpath.com': 2,
#  'rarus.ru': 3,
#  'aeroidea.ru': 2,
#  'gmal.com': 16,
#  'namba.kg': 2,
#  'guruenglish.ru': 7,
#  'skyeng.ru': 32,
#  'mail.ru.il': 1,
#  'gmaiI.com': 1,
#  'lanit.ru': 2,
#  'fas.gov.ru': 1,
#  'mediacom.com': 2,
#  'leomax.ru': 1,
#  'uniqlo.ru': 1,
#  'inbox.lt': 3,
#  'jmail.com': 8,
#  '2018mail.ru': 1,
#  'yaidex.ru': 1,
#  'freenet.de': 2,
#  'test.ru': 34,
#  'gmobis.com': 3,
#  'camozzi.ru': 1,
#  'nspk.ru': 3,
#  'yahoo.com.tr': 1,
#  'its.jnj.com': 1,
#  'diageo.com': 1,
#  'tele2.ru': 2,
#  'bi.zone': 1,
#  'test.com': 7,
#  'danfoss.com': 3,
#  'vershinin.ru': 1,
#  'gamil.com': 8,
#  'roltas.lt': 1,
#  'yahoo.es': 14,
#  'meta.ua': 16,
#  'appodeal.com': 3,
#  'my.com': 4,
#  'ginali.ru': 1,
#  'metro-cc.ru': 3,
#  'ctb.ru': 1,
#  'gmail.comm': 1,
#  'ru.storck.com': 1,
#  'me.com': 46,
#  'yandex.kz': 8,
#  'mail.ru2': 18,
#  'dot-mail.top': 1,
#  'sogaz-clinic.ru': 1,
#  'hessh.sdh': 1,
#  'specta.com': 1,
#  'hm.com': 6,
#  'motot4ik.ru': 1,
#  'jkdfhgkjfdg.gg': 1,
#  'spbrealty.ru': 1,
#  'gmail1.com': 1,
#  'bike4u.ru': 1,
#  'live.com': 9,
#  'alfai.ru': 1,
#  'peleng-group.ru': 1,
#  'ensm.ru': 3,
#  'sigma-it.ru': 2,
#  'siemens.com': 4,
#  'nu.edu.kz': 3,
#  'plaut.com': 1,
#  'aviasales.ru': 3,
#  'murmantara.ru': 1,
#  'tt.tt1': 1,
#  'tut.bu': 1,
#  'oneinc.ru': 2,
#  'open.ru': 5,
#  'rj-games.com': 1,
#  'mail.ri': 8,
#  'abv.bg': 8,
#  'atlascopco.com': 1,
#  'inh-spm.ru': 1,
#  'hillspet.com': 4,
#  'osttpm.ru': 1,
#  'testtest.sadf': 1,
#  'phystech.edu': 5,
#  'grr.la': 31,
#  'yandex.ua': 27,
#  'fsdf.df': 1,
#  'site.ru': 1,
#  'protonmail.com': 6,
#  'kus.com.kz': 2,
#  'ngs.ru': 23,
#  'enazadev.ru': 1,
#  'yandeks.ru': 1,
#  'sfedu.ru': 1,
#  'fidelium10.com': 1,
#  'gmil.com': 7,
#  'profcon.by': 1,
#  'app100.mail.carrotquest.io': 1,
#  'eriell.com': 1,
#  'rzdz.ru': 3,
#  'dizain.work': 1,
#  'surfcoffee.ru': 1,
#  'tutu.ru': 2,
#  'infoin.ru': 1,
#  'dnevnik.ru': 1,
#  'sharklasers.com': 2,
#  'gmx.de': 6,
#  'abbott.com': 2,
#  'just-for.com': 1,
#  'biofabrica.pro': 1,
#  'rt.ru': 4,
#  'cloin.com': 1,
#  'icvladimir.ru': 1,
#  'severstal-ssc.ru': 2,
#  'corp.mail.ru': 5,
#  'severstal.com': 19,
#  'lamoda.ru': 6,
#  'covidien.com': 1,
#  'rg-rus.ru': 1,
#  'emex.ru': 1,
#  'quantori.com': 2,
#  'virueterealty.com': 1,
#  'v-catering.ru': 1,
#  'walla.com': 9,
#  'new-gorod.ru': 1,
#  'iridium-russia.com': 1,
#  'mgpu.ru': 5,
#  'ra-slon.ru': 1,
#  'raiffeisen-life.ru': 1,
#  'cloud.com': 3,
#  'top-career.ru': 1,
#  'kk.nn': 1,
#  'worldskills.ru': 2,
#  'mail.ua': 28,
#  '94mail.ru': 1,
#  'live.ru': 11,
#  'arlift.ru': 1,
#  'energomost.com': 1,
#  'icloud.ru': 5,
#  'sochi.com': 1,
#  'list.ru2': 1,
#  'softline.com': 1,
#  'dgsdgs.sdg': 1,
#  '2yandex.ru': 1,
#  'tehada.com': 1,
#  'mobiogroup.com': 1,
#  'ozon.travel': 1,
#  'cchellenic.com': 1,
#  'narod.ru': 6,
#  'ucloud.com': 3,
#  'azercell.com': 1,
#  'grafitus.lt': 1,
#  'mazars.ru': 1,
#  'artlu.ru': 1,
#  'trbvn.com': 1,
#  'rtural.ru': 1,
#  'gmail.co': 4,
#  'mal.ry': 1,
#  'gmail.test': 1,
#  'binka.me': 3,
#  'stplus.ru': 1,
#  '074gmail.com': 1,
#  'maul.ru': 3,
#  'edfg.tf': 1,
#  'yandex.by': 11,
#  'alfabank.ru': 1,
#  'cci.com.kz': 1,
#  'bruker.com': 1,
#  'papajohns.ru': 1,
#  'ro.ru': 10,
#  'dc2b.ru': 1,
#  'iec-spb.ru': 1,
#  'gmail.gom': 1,
#  'hoya-lens.ru': 2,
#  'malinator.com': 5,
#  'soloviev.me': 1,
#  'mail.bg': 1,
#  '-1968': 1,
#  'storiqa.com': 1,
#  'spk.ru': 1,
#  'x5.ru': 8,
#  'astd.ru': 1,
#  'bb.ru': 1,
#  'unilever.com': 1,
#  'gmil.som': 1,
#  'rgrauto.ru': 1,
#  'gmeil.com': 7,
#  'axa.es': 1,
#  'inloud.com': 1,
#  'mts.by': 1,
#  'traceair.net': 1,
#  'group-ib.com': 1,
#  'gmailm.com': 1,
#  'dlsvet.ru': 1,
#  'gmail.com2': 4,
#  'serrycamp.com': 1,
#  'egstelecom.ru': 1,
#  'mail.ee': 1,
#  'gmai.com': 17,
#  'takeda.com': 2,
#  'dgdfg.ru': 1,
#  'qq.ag': 1,
#  'et.ru': 1,
#  'norbit.ru': 1,
#  'efsol.ru': 1,
#  'avilon.ru': 1,
#  'sborisov.ru': 1,
#  'uralkali.com': 1,
#  'zeppelin.com': 3,
#  'drodo.com': 1,
#  'bogatyrev.me': 1,
#  'altium.com': 1,
#  'daetopravda.ru': 1,
#  'bigmir.net': 13,
#  'mail4gmail.com': 1,
#  'web-geeks.ru': 1,
#  'dorogov-mentor.com': 1,
#  'agile-coach.ru': 1,
#  'lenta.ru': 10,
#  'kuklin.pro': 1,
#  'maximatelecom.ru': 1,
#  'mailnator.com': 4,
#  'test.te': 1,
#  'fromru.com': 1,
#  'umail.uz': 1,
#  'vscenergo.ru': 1,
#  'rpharm.ru': 1,
#  'doksignal.ru': 1,
#  'pcbsoft.ru': 1,
#  '2017gmail.com': 1,
#  'skdayeng.ru': 1,
#  'mail.ru1': 18,
#  'getnada.com': 1,
#  'hyundai.ru': 1,
#  'damir24.ru': 1,
#  'boehringer-ingelheim.com': 1,
#  'cft.ru': 2,
#  'gett.com': 5,
#  'bit2tube.com': 1,
#  'aplana.com': 1,
#  'chmw.ru': 1,
#  'nornik.ru': 3,
#  'kama-crystal.com': 1,
#  'akado-ural.ru': 1,
#  '3mail.ru': 1,
#  'uandex.ru': 4,
#  'strauss-group.ru': 1,
#  'lesaffre.com': 1,
#  'daoffice.ru': 1,
#  'saurida.lt': 1,
#  'sddsf.ru': 1,
#  'asuproject.ru': 1,
#  'maik.ru': 1,
#  'ggggg.email.com': 1,
#  'business-time76.ru': 1,
#  'g5e.com': 2,
#  'mario.ua': 1,
#  'protomail.com': 1,
#  'perestroika30.ru': 1,
#  'googlemail.com': 1,
#  'vladimirnikandrov.me': 1,
#  'peri.ru': 3,
#  'admitad.com': 2,
#  'zabudko.ru': 1,
#  'xy2.info': 1,
#  'mts.ru': 7,
#  'ivolatility.com': 1,
#  'dodopizza.com': 3,
#  'lubimova.com': 1,
#  'gmaildod.com': 1,
#  'doc-mail.net': 1,
#  'sportmaster.ru': 4,
#  'sas.com': 2,
#  'metalline.ru': 1,
#  'navicons.ru': 1,
#  'sibmail.com': 4,
#  'asics.com': 1,
#  'p33.org': 4,
#  'shennun-tea.ru': 1,
#  'nwytg.com': 1,
#  'gcore.lu': 2,
#  'korusconsulting.ru': 4,
#  'subto.ru': 1,
#  'polyus.com': 5,
#  'gmail.com.com.com.com': 1,
#  'yahoo.ru': 2,
#  'ynadex.ru': 2,
#  'baltika.com': 3,
#  'ydbdbd.ru': 1,
#  'gmail.com11': 4,
#  'email.com': 14,
#  'lennybot.me': 14,
#  'yandex.r': 1,
#  'naver.com': 1,
#  'colpal.com': 3,
#  'hjsjdfksdjfh8389.ru': 1,
#  'kng.beeline.ru': 1,
#  'mail-cart.com': 1,
#  'ivcgroup.com': 1,
#  'meel.ry': 1,
#  'fjlkfsljk.ru': 1,
#  'hybrid.ru': 1,
#  'ak.ru': 1,
#  'gmile.com': 1,
#  'yahoo.it': 2,
#  'popup.ru': 1,
#  'cytanet.com.cy': 1,
#  'ya.ryyydd': 1,
#  'sberbank-tele.com': 1,
#  'dmigom.ru': 1,
#  'gmail.vom': 1,
#  'novard.ru': 1,
#  'dvfu.ru': 1,
#  'libero.it': 4,
#  'hot-wifi.ru': 1,
#  'kist.ru': 1,
#  'tt.ru': 1,
#  'lenta.com': 7,
#  'domrf.ru': 2,
#  'orange.com': 2,
#  'list.tu': 3,
#  'legionfarm.com': 2,
#  'rencons.com': 1,
#  'skyeng.r': 1,
#  'edu.tatar.ru': 3,
#  'noaction.ru': 1,
#  'myttk.ru': 1,
#  'yahoo.co.uk': 2,
#  'reactive-agency.ru': 1,
#  'poltank.com': 1,
#  'ukr.net.ua': 1,
#  'rambker.ru': 1,
#  'kcc.com': 4,
#  'securitas.pl': 2,
#  'gmail.cm': 1,
#  'invox.ru': 3,
#  'tandh.ru': 1,
#  'shell.com': 4,
#  'g.mail.ru': 1,
#  'palfinger.com': 1,
#  'rabler.ru': 1,
#  'icloude.com': 1,
#  'gryazeboy.ru': 1,
#  'nordgold.com': 7,
#  'yahdec.ru': 1,
#  'cheb.ru': 1,
#  'biocad.ru': 9,
#  'pharmtrend.ru': 1,
#  'dostavista.ru': 4,
#  'trotsko.fastmail.fm': 1,
#  'yamoney.ru': 2,
#  'human-resource.ru': 1,
#  'adecco.ru': 4,
#  'hlebozavod9.ru12': 1,
#  'yaxdex.ru': 1,
#  'beercard.ru': 2,
#  'daimler.com': 1,
#  'wargaming.net': 5,
#  'leroymerlin.ru': 6,
#  'danone.com': 3,
#  'novateh.ru': 1,
#  'test1212122112121221212.ru': 1,
#  'db.com': 3,
#  'apo-rus.com': 1,
#  'adidas.com': 2,
#  'oilfund.az': 1,
#  'auchan.ru': 1,
#  'airliquide.com': 2,
#  'nordavia.ru1': 1,
#  'emkspb.ru': 1,
#  'edu.hse.ru3': 1,
#  'bc.com': 1,
#  '30gmail.com': 1,
#  'rucontent.ru': 1,
#  'yandex.ru2': 9,
#  'gmacl.com': 1,
#  're.te': 1,
#  'sadfd.dd': 1,
#  'koriphey.ru': 2,
#  'topperfil.es': 1,
#  'gen.tech': 1,
#  'srosl.ru': 1,
#  'web.de': 5,
#  'argos-m.ru': 1,
#  'iclout.com': 1,
#  'krc.karelia.ru': 1,
#  'volga.rt.ru': 2,
#  'zvet.ru': 2,
#  'festial.e': 1,
#  'test.tests': 1,
#  'unity.ru': 1,
#  'culinaryon.com': 1,
#  'ural.rt.ru': 4,
#  'egeg.ru': 1,
#  'prospectacy.ru': 1,
#  'ts.fujitsu.com': 1,
#  'exkurs.ru': 1,
#  'askonalife.com': 1,
#  'pridemarketing.ru': 2,
#  'sdsdfdtest.ru': 1,
#  'itech-art.com': 1,
#  'vtb.ru': 3,
#  '1768gmail.com': 1,
#  'isisis.ry': 1,
#  's1987.ru': 1,
#  'test.rtrtrt': 1,
#  'tts.ru': 1,
#  'mail.ru11': 3,
#  'hotbox.ru': 2,
#  'email.ru': 7,
#  'mali.ru': 3,
#  'sladis.ru': 1,
#  'sobiraloff.ru': 1,
#  'kraftmilk.com': 1,
#  'aplica.ru': 1,
#  'spatium.ru': 1,
#  'acslog.ru': 1,
#  'loud.com': 1,
#  '10mail.org': 2,
#  'aviaberkut.ru': 1,
#  'mhshop.ru': 1,
#  'sktuote.ru': 1,
#  'modulbank.ru': 1,
#  'walla.co.il': 3,
#  'list.ru1': 2,
#  'test.kg': 1,
#  'p33.orgш': 1,
#  'yndex.ru': 6,
#  'yabloki19.ru': 1,
#  'sphere-ic.ru': 1,
#  'space307.com': 2,
#  'digitalizm.com': 1,
#  'osgrm.ru': 1,
#  'iprospect.ru': 1,
#  'kapitonov.org': 1,
#  'mskh.am': 2,
#  'carprice.ru': 1,
#  'retal.ru': 1,
#  'phoenix-llc.ru': 1,
#  'fizmat.kz': 1,
#  'gmaila.com': 1,
#  'вгд.ру': 1,
#  'erghg.ry': 1,
#  'ru.ibm.com': 1,
#  'nordavia.ru': 5,
#  'metaclay.com': 1,
#  'i-kompas.ru': 1,
#  'jugru.org': 1,
#  'ostrovok.ru': 2,
#  'ryy.ru': 1,
#  'asdasd.ru': 2,
#  'rr.rr': 1,
#  'pepsico.com': 2,
#  'bougakov.com': 1,
#  'inbow.ru': 1,
#  'kidzania.ru': 1,
#  'arview.pro': 1,
#  'hotmail.fr': 2,
#  'belugagroup.ru': 2,
#  'azurgames.com': 1,
#  'beeline.ru': 1,
#  'online.ua': 1,
#  'skyeng.com': 2,
#  'outliik.com': 1,
#  'havi.com': 2,
#  'mgppu.ru': 1,
#  'lis.ru': 1,
#  'erg.kz': 2,
#  'ub.edu': 1,
#  'zvezdnaya.ru': 1,
#  'runex.ru': 1,
#  'ru.knightfrank.com': 1,
#  'idealscorp.com': 1,
#  'outlook.ru': 1,
#  'ynade.ru': 1,
#  'askonalife.ru': 1,
#  'forafarm.ru': 1,
#  'divakovdance.ru': 1,
#  'tbenergo.ru': 1,
#  'tulatochmash.ru': 1,
#  'henkel.com': 4,
#  'valeria.com': 1,
#  'gmail.kg': 1,
#  'huhtamaki.com': 1,
#  'renol.ru': 1,
#  'gaimal.con': 1,
#  'certit.ru': 1,
#  'institute-bm.com': 1,
#  'qq.qw': 1,
#  'virbac.me': 1,
#  'priberi.ru': 1,
#  'redmond.company': 1,
#  'azan.ru': 1,
#  'sdfjhs.ru': 1,
#  'gazprom-neft.ru': 8,
#  'bayaderagroup.com': 1,
#  'imbox.ru': 3,
#  'pokrovskiy.me': 1,
#  '126.com': 1,
#  'horsgroup.com': 1,
#  'outluk.ru': 1,
#  'lppsa.com': 3,
#  'gmail.cim': 2,
#  'yandex.tu': 1,
#  '1mail.ru': 3,
#  'mail.eu': 1,
#  'yahoo.fr': 4,
#  'ancor.ru': 1,
#  'tn.ru': 5,
#  '3003mail.ru': 1,
#  'qq.hs': 1,
#  'angaratech.ru': 2,
#  'primezone.ru': 1,
#  'tmnovo.ru': 1,
#  'compel.ru': 1,
#  'baranchuk.com': 2,
#  'helenbloom.ru': 1,
#  'shire.com': 1,
#  'gmsil.com': 5,
#  'tk73.ru': 1,
#  'skyeng1.ru': 1,
#  'yahoo.ro': 1,
#  'hiq.ru': 1,
#  'pirelli.com': 2,
#  'monopoly.su': 1,
#  'iclound.com': 1,
#  'orange.fr': 1,
#  'it-kurs.com': 1,
#  'gmli.com': 1,
#  'ua.fm': 2,
#  'growtalent.ru': 1,
#  'inboz.ru': 1,
#  'inbox.ru2': 3,
#  'bl.ru': 2,
#  'factorymarket.com': 1,
#  'pernod-ricard.com': 1,
#  'maukl.ru': 1,
#  'gmail.kom': 1,
#  'gmaik.com': 1,
#  'urfu.me': 2,
#  'ays-club.ru': 1,
#  'tra.ai': 1,
#  'dngroup.ru': 1,
#  'drugnevest.ru': 1,
#  'sm-komandor.ru': 1,
#  'okc11.ru': 1,
#  '1c.com': 3,
#  'incotex.ru': 1,
#  'gnail.com': 3,
#  'devnull.facebook.com': 15,
#  'vestar.net': 1,
#  'ralf.ru': 1,
#  'avi-pro.ru': 1,
#  'skyeng.ry': 1,
#  'ru.pvmgrp.com': 2,
#  'yahoo.com.br': 1,
#  'hotmail.de': 2,
#  'tester.ru': 1,
#  'tass.ru': 1,
#  'test.email255': 1,
#  'bodnar.ru': 1,
#  'hotmail.es': 8,
#  'bbr.ru': 1,
#  'maii.ru': 2,
#  'forbes.ru': 1,
#  'vumk.com': 1,
#  'bhu.kg': 1,
#  'sdtfhg.ru': 1,
#  'picaso-3d.ru': 1,
#  'english-smart.ru': 1,
#  'bmw.com': 1,
#  'rjejdj.dde': 1,
#  'stalcom.com': 1,
#  'yandrx.ru': 2,
#  'cashwagon.com': 1,
#  'kzn.beeline.ru': 1,
#  'icloud.mail': 1,
#  'alpari.org': 3,
#  'infovizion.ru': 1,
#  'method-agency.ru': 1,
#  'br.ru': 1,
#  '72.ru': 1,
#  'vyatplita.ru': 1,
#  'qw.rp': 1,
#  '2009.com': 1,
#  'yadex.ru': 4,
#  'dasglobal.ru': 1,
#  'qmail.ru': 1,
#  'dial-parts.ru': 1,
#  'egis.ru': 3,
#  'test.tt': 1,
#  'part-iskra.org': 1,
#  'ezweb.ne.jp': 1,
#  'amrest.eu': 2,
#  'live.co.uk': 2,
#  'ikea.com': 7,
#  'urengoy.ru': 1,
#  'hotmail.it': 2,
#  'niiegp.ru': 1,
#  'wmkc.ru': 1,
#  'school1465.ru': 1,
#  'ovbport.ru': 1,
#  'test.qq': 1,
#  'kbexpert.ru': 1,
#  'artpaints.ru': 2,
#  'askona.ru': 2,
#  'dell.com': 1,
#  'yesonline.su': 1,
#  'goods.ru': 1,
#  'test.email681': 1,
#  'electronicalabel.ru': 1,
#  'sdventures.com': 3,
#  'ds032.com': 1,
#  'petrovich.ru': 1,
#  'kokoskeria.com': 1,
#  '139.com': 1,
#  'mama.ru': 1,
#  'ihoo.com': 1,
#  'list.ruu': 1,
#  'klkf.ru': 1,
#  'fadente.es': 1,
#  'mjr.ru': 1,
#  'mail.ru0': 1,
#  '156.com': 1,
#  'asap.msk.ru': 1,
#  'mgimo.ru': 1,
#  'vseinstrumenti.ru': 1,
#  'shaw.ca': 1,
#  'xandex.ru': 1,
#  'nissan.ru': 1,
#  'chumov.ru': 1,
#  'delvedeeper.com': 1,
#  'list.com': 1,
#  'ghsddsg.dsg': 1,
#  'indatalabs.com': 2,
#  'mail.ru123': 3,
#  'gmal.ru': 1,
#  'some.ru': 1,
#  'gmail.caws': 1,
#  'redmadrobot.com': 1,
#  '279.ru': 1,
#  'knaufinsulation.com': 1,
#  'test.dfg': 1,
#  'boardriders.com': 2,
#  'price-media.ru': 1,
#  'lmail.com': 1,
#  'group2901.com': 1,
#  'iclaud.com': 1,
#  'parity.digital': 1,
#  'propellerads.net': 1,
#  'molodost.bz': 1,
#  'nail.ru': 4,
#  'eutelsat.com': 1,
#  'fgdfhgfd.ru': 1,
#  'ktkd.ru': 1,
#  'iclod.com': 2,
#  'dent.md': 1,
#  'moscow-leningradskaya.ru': 1,
#  'trendufa.ru': 1,
#  'calltouch.net': 1,
#  'veb-leasing.ru': 1,
#  'icoud.com': 2,
#  'school777.ru': 1,
#  '2gmail.com': 1,
#  'sveza.com': 1,
#  'ves-media.com': 1,
#  'imail.ru': 1,
#  'ru.ey.com': 1,
#  'o3enzyme.com': 1,
#  'geropharm.com': 1,
#  'burgerking.ru': 4,
#  'meil.ru': 2,
#  'tdaero.ru': 1,
#  'interlingua.edu.ru': 1,
#  'globalprinting.ru': 1,
#  'skibinski.nsk.ru': 1,
#  'vichy.ru': 1,
#  '98gmail.com': 1,
#  'isla.vc': 1,
#  'yahoo.co.jp': 1,
#  'facebook.com': 2,
#  'hansa.ru': 1,
#  'ottoruss.ru': 1,
#  'atomproekt.com': 1,
#  'heros3.com': 2,
#  'dwteam.ru': 1,
#  'libertyrus.ru': 1,
#  'azyfuy.ry': 1,
#  'junglejobs.ru': 1,
#  'mil.ru': 4,
#  'airastana.com': 4,
#  'geosplit.ru': 1,
#  '2gis.ru': 1,
#  'wfff.qv': 1,
#  'qiwi.com': 4,
#  'ridzel.ru': 1,
#  'zimail.ru': 1,
#  'jdecoffee.com': 1,
#  'bshg.com': 1,
#  'afitness.ru': 1,
#  'fly-tech.ru': 1,
#  'awesta.ru': 1,
#  'jj.gh': 1,
#  'ua.ru': 1,
#  'russianpost.ru': 1,
#  'nrservice.ru': 1,
#  'gre.la': 1,
#  'yahoo.ca': 2,
#  'merkatorgroup.ru': 1,
#  'k.ru': 1,
#  'sogaz.ru': 1,
#  'rambler.com': 1,
#  'vingrad.ru': 1,
#  'ssscredit.ru': 1,
#  'olympus-europa.com': 1,
#  'unisender.com': 1,
#  'gymn1sam.ru': 1,
#  'trapezatour.md': 1,
#  'pochtamt.ru': 1,
#  'itechart-group.com': 1,
#  'nipt.ru': 1,
#  'vizart.tv': 1,
#  'airpush.com': 1,
#  'ferronordic.com': 1,
#  'globus.ru': 1,
#  'wemakefab.ru': 1,
#  'smartscribe.biz': 1,
#  'familyiv.com': 1,
#  'drgdfhh.ru': 1,
#  'effem.com': 1,
#  'mail.con': 1,
#  'pro1.ru': 1,
#  'zhaikmunai.kz': 2,
#  'im-agency.ru': 1,
#  'pk.ru': 1,
#  'maill.ru': 3,
#  'mmm.ru': 1,
#  'yandex.rux': 1,
#  'servier.com': 1,
#  'revolut.com': 2,
#  'maiil.ru': 1,
#  'vezet.ru': 1,
#  'fdlgkj.ruu': 1,
#  'dydysbbd.ru': 1,
#  'kharkov.ua': 1,
#  'ehl.ch': 1,
#  'il.com': 2,
#  'irisdigital.ru': 1,
#  'yanddx.ru': 1,
#  'gmaie.com': 1,
#  'gmale.com': 1,
#  'nationalropeways.ru': 1,
#  'vmani.com': 2,
#  'lobsterfilm.com': 1,
#  'wer.ru': 2,
#  'gotar.ru': 1,
#  'wp.pl': 1,
#  'itc-logistic.ru': 1,
#  'eldorado.ru': 1,
#  'el-com.ru': 1,
#  'elmi.ru': 1,
#  'mail2k.ru': 1,
#  'ge.com': 2,
#  'gmail.coam': 1,
#  'tsum.ru': 2,
#  'ekoniva.com': 2,
#  'festial.es': 1,
#  'yandex.ru1': 8,
#  'axzon.eu': 1,
#  'mustangtk.ru': 1,
#  'kru.ru': 1,
#  'aeroflot.ru': 1,
#  'maaaail.rru': 1,
#  'jet.msk': 1,
#  'slyeng.ru': 1,
#  'skyengo.ru': 1,
#  'mtglobal.ru': 1,
#  'surw.ru': 1,
#  'ser.ty': 1,
#  'molinator111.ru': 1,
#  'sch2009.net': 1,
#  'arbtr.legal': 1,
#  'mail.edu': 1,
#  'artox-media.ru': 1,
#  'alloka.ru': 1,
#  'fun-box.ru': 1,
#  'lexkeller.ru': 1,
#  'avrp.ru': 1,
#  'solgarvitamin.ru': 1,
#  'sdfsdf.com': 1,
#  'ghrh.gh': 1,
#  'ru.nestle.com': 3,
#  'corning.com': 1,
#  'cosmostone.ru': 1,
#  'googi.com': 1,
#  'mindbox.ru': 2,
#  'lge.com': 2,
#  'crm.st': 1,
#  'infosec.ru': 1,
#  'chelcom.ru': 1,
#  'loreal.com': 2,
#  'koskogoup.ru': 1,
#  'issart.com': 1,
#  'hotmail.gr1': 1,
#  'yauzacabel.ru': 1,
#  'tumo.org': 4,
#  'frtk.ru': 1,
#  'gm32ail.com': 1,
#  'lksdjfl.ru': 1,
#  'yasgku.org': 1,
#  'yangex.ru': 2,
#  'newmail.ru': 1,
#  'rusimport.ru': 1,
#  'id-logistics.com': 2,
#  'pflb.ru': 1,
#  'playgendary.com': 2,
#  '74.ru': 2,
#  'resenergo.ru': 1,
#  'missionfoods.com': 1,
#  'polyusgold.com': 1,
#  'alice.it': 1,
#  'skyeng.co': 3,
#  'obi.ru': 1,
#  'svel.ru': 2,
#  'thomasint.ru': 1,
#  'richemont.com': 1,
#  'yandex,ru': 1,
#  'testovaya.ru': 1,
#  'misslo.com': 1,
#  'liftmarketing.ru': 1,
#  'poliada.pro': 1,
#  'bory.ru': 1,
#  'mailb.com': 2,
#  'testqwerty.com': 1,
#  'itup.tech': 1,
#  'skolkovo.ru': 3,
#  'iclud.com': 1,
#  'sovacapital.com': 1,
#  'roderk.ru': 1,
#  'sovcombank.ru': 1,
#  'wikrgroup.com': 1,
#  'therubin.ru': 1,
#  'dev.com': 6,
#  'kak.ru': 1,
#  'bek.ru': 1,
#  'gmaol.com': 2,
#  'uchinovoe.ru': 1,
#  'vkcode.ru': 1,
#  'pma.su': 1,
#  'hotmai.it': 1,
#  'alfa-transit.com': 1,
#  'tatar.ru': 2,
#  '02gmail.ru': 1,
#  'papakaya.com': 1,
#  'smr.bcs.ru': 1,
#  'cushwake.com': 1,
#  'lika-tur.ru': 1,
#  'velesstroy.com': 1,
#  'ail.com': 1,
#  'devnullmail.com': 3,
#  'goldensim.ru': 1,
#  'gmail.comsa': 1,
#  'geops.ru': 1,
#  'testmail.ru': 2,
#  'yandeх.ru': 1,
#  'guerillamail.com': 2,
#  'perfobur.com': 1,
#  'kostomuksha.ru': 1,
#  'dataduck.com': 1,
#  'qq.hr': 1,
#  'tochka.com': 1,
#  'mail.fr': 1,
#  'konstanti.ru': 1,
#  'skyeng.rd': 1,
#  'areva.com': 1,
#  '608gmail.com': 1,
#  'sibir.rt.ru': 1,
#  'fesco.com': 2,
#  'onego.ru': 2,
#  'litsey2.ru': 1,
#  'uchitelnik.ru': 1,
#  'beloyarka.com': 1,
#  'louder.ru': 1,
#  'email.it': 1,
#  'gmaii.com': 1,
#  'jilfond.ru': 1,
#  'bb.bb': 1,
#  'gmfdsfa3.com': 1,
#  'yanex.ru': 4,
#  'aall.ru': 1,
#  'mailsource.info': 1,
#  'ls.ru': 1,
#  'baskir.ru': 1,
#  'teux.ru': 1,
#  '11gmail.com': 2,
#  'gmaill.com': 4,
#  'bk.during': 1,
#  'inbox.ru9': 1,
#  'emil.com': 1,
#  'difff.ru': 1,
#  'fleetcor.ru': 1,
#  'verra.ru': 1,
#  'gimail.com': 1,
#  'posterscope.ru': 1,
#  'fjskfd.ru': 1,
#  'fgh.ru': 1,
#  'morois.ru': 1,
#  'maiinator.com': 1,
#  'slb.com': 1,
#  'inn.ru': 4,
#  'accenture.com': 2,
#  'licey21.su': 1,
#  'alov.me': 1,
#  'tvel.ru': 1,
#  'uker.net': 1,
#  'dfgdfgdfg.ru': 1,
#  'qw.mi': 1,
#  'ovanesov.ru': 1,
#  'egor.im': 1,
#  ...}

# %% [markdown]
# ## EXTRA
#
# Мы приготовили еще одно задание для тех, кто не хочет останавливаться. Оно чуть сложнее, чем предыдущие, но не требует никаких дополнительных знаний.

# %% [markdown]
# ### Задание 8
# А теперь попробуй найти количество вхождений каждого домена (как в задании 7) только с использованием циклов и операторов, не применяя встроенные функции и методы.

# %%
# Hint: решение может быть очень коротким, до 6 строк

count_unic_domain = dict()
for name_domain in domains:
    if name_domain not in count_unic_domain:
        count_unic_domain[name_domain] = 1
    else: 
        count_unic_domain[name_domain] += 1
count_unic_domain
# Out:
# {'mail.ru': 16367,
#  'yandex.ru': 6245,
#  'gmail.com': 17715,
#  'i-free.com': 1,
#  'icloud.com': 743,
#  'tandem.ru': 1,
#  'inbox.ru': 855,
#  'ukr.net': 210,
#  'yum.com': 3,
#  'bk.ru': 1530,
#  'qq.com': 4,
#  'inbox.lv': 97,
#  'yandex.com': 36,
#  'veeam.com': 1,
#  'list.ru': 899,
#  'yahoo.com': 239,
#  'ya.ru': 354,
#  'mail.com': 123,
#  'rambler.ru': 777,
#  'ex.ru': 1,
#  'atomrus.ru': 4,
#  'mai.ru': 20,
#  'rngoil.ru': 1,
#  'qw.km': 1,
#  'gmail.coom': 1,
#  'hotmail.com': 217,
#  'ibox.ru': 1,
#  'egat.co.th': 1,
#  'kinross.com': 14,
#  'gmail.com1': 22,
#  'mail.ry': 11,
#  'upr.mnsk.rw.by': 1,
#  'bigbadaboom.com': 231,
#  'vayner.ru': 1,
#  'manychat.com': 1,
#  'krastsvetmet.ru': 10,
#  'index.ru': 1,
#  'gmail.ru': 167,
#  'seznam.cz': 8,
#  'gamail.com': 8,
#  'croc.ru': 7,
#  'fircroft.com': 1,
#  'asd.it': 1,
#  'outlook.com': 63,
#  'provectus.com': 2,
#  'i.ua': 40,
#  'tut.by': 37,
#  'hilti.com': 7,
#  'yandex.ry': 4,
#  'ramler.ru': 1,
#  'rb.com': 3,
#  'bnpparibas.com': 1,
#  'wweb.kz': 1,
#  'pr3.eu': 1,
#  'nm.ru': 5,
#  '12storeez.com': 1,
#  'decathlon.com': 15,
#  'msn.com': 3,
#  'a-sign.ru': 1,
#  'gmail.con': 24,
#  'e1.ru': 6,
#  'usa.com': 1,
#  'hettich.ru': 1,
#  'playtika.com': 1,
#  'example.com': 16,
#  'ik-mercury.ru': 1,
#  'qq.sl': 1,
#  'qmail.com': 9,
#  '2107school.ru': 1,
#  'yamed.ru': 1,
#  'picksell.ru': 1,
#  'cloud.ru': 1,
#  'sbcglobal.net': 3,
#  'ss.ru': 1,
#  'test.email7': 1,
#  'a.bc': 1,
#  'dl-trans.ru': 1,
#  'yandex-team.ru': 12,
#  'euroml.ru': 1,
#  'lift.ru': 3,
#  'divisadero.es': 2,
#  'puig.com': 1,
#  'autodata.ru': 1,
#  'furgon-mk.ru': 1,
#  'kambalov.ru': 1,
#  'outlook.es': 4,
#  'akdn.org': 1,
#  'truckerpath.com': 2,
#  'rarus.ru': 3,
#  'aeroidea.ru': 2,
#  'gmal.com': 16,
#  'namba.kg': 2,
#  'guruenglish.ru': 7,
#  'skyeng.ru': 32,
#  'mail.ru.il': 1,
#  'gmaiI.com': 1,
#  'lanit.ru': 2,
#  'fas.gov.ru': 1,
#  'mediacom.com': 2,
#  'leomax.ru': 1,
#  'uniqlo.ru': 1,
#  'inbox.lt': 3,
#  'jmail.com': 8,
#  '2018mail.ru': 1,
#  'yaidex.ru': 1,
#  'freenet.de': 2,
#  'test.ru': 34,
#  'gmobis.com': 3,
#  'camozzi.ru': 1,
#  'nspk.ru': 3,
#  'yahoo.com.tr': 1,
#  'its.jnj.com': 1,
#  'diageo.com': 1,
#  'tele2.ru': 2,
#  'bi.zone': 1,
#  'test.com': 7,
#  'danfoss.com': 3,
#  'vershinin.ru': 1,
#  'gamil.com': 8,
#  'roltas.lt': 1,
#  'yahoo.es': 14,
#  'meta.ua': 16,
#  'appodeal.com': 3,
#  'my.com': 4,
#  'ginali.ru': 1,
#  'metro-cc.ru': 3,
#  'ctb.ru': 1,
#  'gmail.comm': 1,
#  'ru.storck.com': 1,
#  'me.com': 46,
#  'yandex.kz': 8,
#  'mail.ru2': 18,
#  'dot-mail.top': 1,
#  'sogaz-clinic.ru': 1,
#  'hessh.sdh': 1,
#  'specta.com': 1,
#  'hm.com': 6,
#  'motot4ik.ru': 1,
#  'jkdfhgkjfdg.gg': 1,
#  'spbrealty.ru': 1,
#  'gmail1.com': 1,
#  'bike4u.ru': 1,
#  'live.com': 9,
#  'alfai.ru': 1,
#  'peleng-group.ru': 1,
#  'ensm.ru': 3,
#  'sigma-it.ru': 2,
#  'siemens.com': 4,
#  'nu.edu.kz': 3,
#  'plaut.com': 1,
#  'aviasales.ru': 3,
#  'murmantara.ru': 1,
#  'tt.tt1': 1,
#  'tut.bu': 1,
#  'oneinc.ru': 2,
#  'open.ru': 5,
#  'rj-games.com': 1,
#  'mail.ri': 8,
#  'abv.bg': 8,
#  'atlascopco.com': 1,
#  'inh-spm.ru': 1,
#  'hillspet.com': 4,
#  'osttpm.ru': 1,
#  'testtest.sadf': 1,
#  'phystech.edu': 5,
#  'grr.la': 31,
#  'yandex.ua': 27,
#  'fsdf.df': 1,
#  'site.ru': 1,
#  'protonmail.com': 6,
#  'kus.com.kz': 2,
#  'ngs.ru': 23,
#  'enazadev.ru': 1,
#  'yandeks.ru': 1,
#  'sfedu.ru': 1,
#  'fidelium10.com': 1,
#  'gmil.com': 7,
#  'profcon.by': 1,
#  'app100.mail.carrotquest.io': 1,
#  'eriell.com': 1,
#  'rzdz.ru': 3,
#  'dizain.work': 1,
#  'surfcoffee.ru': 1,
#  'tutu.ru': 2,
#  'infoin.ru': 1,
#  'dnevnik.ru': 1,
#  'sharklasers.com': 2,
#  'gmx.de': 6,
#  'abbott.com': 2,
#  'just-for.com': 1,
#  'biofabrica.pro': 1,
#  'rt.ru': 4,
#  'cloin.com': 1,
#  'icvladimir.ru': 1,
#  'severstal-ssc.ru': 2,
#  'corp.mail.ru': 5,
#  'severstal.com': 19,
#  'lamoda.ru': 6,
#  'covidien.com': 1,
#  'rg-rus.ru': 1,
#  'emex.ru': 1,
#  'quantori.com': 2,
#  'virueterealty.com': 1,
#  'v-catering.ru': 1,
#  'walla.com': 9,
#  'new-gorod.ru': 1,
#  'iridium-russia.com': 1,
#  'mgpu.ru': 5,
#  'ra-slon.ru': 1,
#  'raiffeisen-life.ru': 1,
#  'cloud.com': 3,
#  'top-career.ru': 1,
#  'kk.nn': 1,
#  'worldskills.ru': 2,
#  'mail.ua': 28,
#  '94mail.ru': 1,
#  'live.ru': 11,
#  'arlift.ru': 1,
#  'energomost.com': 1,
#  'icloud.ru': 5,
#  'sochi.com': 1,
#  'list.ru2': 1,
#  'softline.com': 1,
#  'dgsdgs.sdg': 1,
#  '2yandex.ru': 1,
#  'tehada.com': 1,
#  'mobiogroup.com': 1,
#  'ozon.travel': 1,
#  'cchellenic.com': 1,
#  'narod.ru': 6,
#  'ucloud.com': 3,
#  'azercell.com': 1,
#  'grafitus.lt': 1,
#  'mazars.ru': 1,
#  'artlu.ru': 1,
#  'trbvn.com': 1,
#  'rtural.ru': 1,
#  'gmail.co': 4,
#  'mal.ry': 1,
#  'gmail.test': 1,
#  'binka.me': 3,
#  'stplus.ru': 1,
#  '074gmail.com': 1,
#  'maul.ru': 3,
#  'edfg.tf': 1,
#  'yandex.by': 11,
#  'alfabank.ru': 1,
#  'cci.com.kz': 1,
#  'bruker.com': 1,
#  'papajohns.ru': 1,
#  'ro.ru': 10,
#  'dc2b.ru': 1,
#  'iec-spb.ru': 1,
#  'gmail.gom': 1,
#  'hoya-lens.ru': 2,
#  'malinator.com': 5,
#  'soloviev.me': 1,
#  'mail.bg': 1,
#  '-1968': 1,
#  'storiqa.com': 1,
#  'spk.ru': 1,
#  'x5.ru': 8,
#  'astd.ru': 1,
#  'bb.ru': 1,
#  'unilever.com': 1,
#  'gmil.som': 1,
#  'rgrauto.ru': 1,
#  'gmeil.com': 7,
#  'axa.es': 1,
#  'inloud.com': 1,
#  'mts.by': 1,
#  'traceair.net': 1,
#  'group-ib.com': 1,
#  'gmailm.com': 1,
#  'dlsvet.ru': 1,
#  'gmail.com2': 4,
#  'serrycamp.com': 1,
#  'egstelecom.ru': 1,
#  'mail.ee': 1,
#  'gmai.com': 17,
#  'takeda.com': 2,
#  'dgdfg.ru': 1,
#  'qq.ag': 1,
#  'et.ru': 1,
#  'norbit.ru': 1,
#  'efsol.ru': 1,
#  'avilon.ru': 1,
#  'sborisov.ru': 1,
#  'uralkali.com': 1,
#  'zeppelin.com': 3,
#  'drodo.com': 1,
#  'bogatyrev.me': 1,
#  'altium.com': 1,
#  'daetopravda.ru': 1,
#  'bigmir.net': 13,
#  'mail4gmail.com': 1,
#  'web-geeks.ru': 1,
#  'dorogov-mentor.com': 1,
#  'agile-coach.ru': 1,
#  'lenta.ru': 10,
#  'kuklin.pro': 1,
#  'maximatelecom.ru': 1,
#  'mailnator.com': 4,
#  'test.te': 1,
#  'fromru.com': 1,
#  'umail.uz': 1,
#  'vscenergo.ru': 1,
#  'rpharm.ru': 1,
#  'doksignal.ru': 1,
#  'pcbsoft.ru': 1,
#  '2017gmail.com': 1,
#  'skdayeng.ru': 1,
#  'mail.ru1': 18,
#  'getnada.com': 1,
#  'hyundai.ru': 1,
#  'damir24.ru': 1,
#  'boehringer-ingelheim.com': 1,
#  'cft.ru': 2,
#  'gett.com': 5,
#  'bit2tube.com': 1,
#  'aplana.com': 1,
#  'chmw.ru': 1,
#  'nornik.ru': 3,
#  'kama-crystal.com': 1,
#  'akado-ural.ru': 1,
#  '3mail.ru': 1,
#  'uandex.ru': 4,
#  'strauss-group.ru': 1,
#  'lesaffre.com': 1,
#  'daoffice.ru': 1,
#  'saurida.lt': 1,
#  'sddsf.ru': 1,
#  'asuproject.ru': 1,
#  'maik.ru': 1,
#  'ggggg.email.com': 1,
#  'business-time76.ru': 1,
#  'g5e.com': 2,
#  'mario.ua': 1,
#  'protomail.com': 1,
#  'perestroika30.ru': 1,
#  'googlemail.com': 1,
#  'vladimirnikandrov.me': 1,
#  'peri.ru': 3,
#  'admitad.com': 2,
#  'zabudko.ru': 1,
#  'xy2.info': 1,
#  'mts.ru': 7,
#  'ivolatility.com': 1,
#  'dodopizza.com': 3,
#  'lubimova.com': 1,
#  'gmaildod.com': 1,
#  'doc-mail.net': 1,
#  'sportmaster.ru': 4,
#  'sas.com': 2,
#  'metalline.ru': 1,
#  'navicons.ru': 1,
#  'sibmail.com': 4,
#  'asics.com': 1,
#  'p33.org': 4,
#  'shennun-tea.ru': 1,
#  'nwytg.com': 1,
#  'gcore.lu': 2,
#  'korusconsulting.ru': 4,
#  'subto.ru': 1,
#  'polyus.com': 5,
#  'gmail.com.com.com.com': 1,
#  'yahoo.ru': 2,
#  'ynadex.ru': 2,
#  'baltika.com': 3,
#  'ydbdbd.ru': 1,
#  'gmail.com11': 4,
#  'email.com': 14,
#  'lennybot.me': 14,
#  'yandex.r': 1,
#  'naver.com': 1,
#  'colpal.com': 3,
#  'hjsjdfksdjfh8389.ru': 1,
#  'kng.beeline.ru': 1,
#  'mail-cart.com': 1,
#  'ivcgroup.com': 1,
#  'meel.ry': 1,
#  'fjlkfsljk.ru': 1,
#  'hybrid.ru': 1,
#  'ak.ru': 1,
#  'gmile.com': 1,
#  'yahoo.it': 2,
#  'popup.ru': 1,
#  'cytanet.com.cy': 1,
#  'ya.ryyydd': 1,
#  'sberbank-tele.com': 1,
#  'dmigom.ru': 1,
#  'gmail.vom': 1,
#  'novard.ru': 1,
#  'dvfu.ru': 1,
#  'libero.it': 4,
#  'hot-wifi.ru': 1,
#  'kist.ru': 1,
#  'tt.ru': 1,
#  'lenta.com': 7,
#  'domrf.ru': 2,
#  'orange.com': 2,
#  'list.tu': 3,
#  'legionfarm.com': 2,
#  'rencons.com': 1,
#  'skyeng.r': 1,
#  'edu.tatar.ru': 3,
#  'noaction.ru': 1,
#  'myttk.ru': 1,
#  'yahoo.co.uk': 2,
#  'reactive-agency.ru': 1,
#  'poltank.com': 1,
#  'ukr.net.ua': 1,
#  'rambker.ru': 1,
#  'kcc.com': 4,
#  'securitas.pl': 2,
#  'gmail.cm': 1,
#  'invox.ru': 3,
#  'tandh.ru': 1,
#  'shell.com': 4,
#  'g.mail.ru': 1,
#  'palfinger.com': 1,
#  'rabler.ru': 1,
#  'icloude.com': 1,
#  'gryazeboy.ru': 1,
#  'nordgold.com': 7,
#  'yahdec.ru': 1,
#  'cheb.ru': 1,
#  'biocad.ru': 9,
#  'pharmtrend.ru': 1,
#  'dostavista.ru': 4,
#  'trotsko.fastmail.fm': 1,
#  'yamoney.ru': 2,
#  'human-resource.ru': 1,
#  'adecco.ru': 4,
#  'hlebozavod9.ru12': 1,
#  'yaxdex.ru': 1,
#  'beercard.ru': 2,
#  'daimler.com': 1,
#  'wargaming.net': 5,
#  'leroymerlin.ru': 6,
#  'danone.com': 3,
#  'novateh.ru': 1,
#  'test1212122112121221212.ru': 1,
#  'db.com': 3,
#  'apo-rus.com': 1,
#  'adidas.com': 2,
#  'oilfund.az': 1,
#  'auchan.ru': 1,
#  'airliquide.com': 2,
#  'nordavia.ru1': 1,
#  'emkspb.ru': 1,
#  'edu.hse.ru3': 1,
#  'bc.com': 1,
#  '30gmail.com': 1,
#  'rucontent.ru': 1,
#  'yandex.ru2': 9,
#  'gmacl.com': 1,
#  're.te': 1,
#  'sadfd.dd': 1,
#  'koriphey.ru': 2,
#  'topperfil.es': 1,
#  'gen.tech': 1,
#  'srosl.ru': 1,
#  'web.de': 5,
#  'argos-m.ru': 1,
#  'iclout.com': 1,
#  'krc.karelia.ru': 1,
#  'volga.rt.ru': 2,
#  'zvet.ru': 2,
#  'festial.e': 1,
#  'test.tests': 1,
#  'unity.ru': 1,
#  'culinaryon.com': 1,
#  'ural.rt.ru': 4,
#  'egeg.ru': 1,
#  'prospectacy.ru': 1,
#  'ts.fujitsu.com': 1,
#  'exkurs.ru': 1,
#  'askonalife.com': 1,
#  'pridemarketing.ru': 2,
#  'sdsdfdtest.ru': 1,
#  'itech-art.com': 1,
#  'vtb.ru': 3,
#  '1768gmail.com': 1,
#  'isisis.ry': 1,
#  's1987.ru': 1,
#  'test.rtrtrt': 1,
#  'tts.ru': 1,
#  'mail.ru11': 3,
#  'hotbox.ru': 2,
#  'email.ru': 7,
#  'mali.ru': 3,
#  'sladis.ru': 1,
#  'sobiraloff.ru': 1,
#  'kraftmilk.com': 1,
#  'aplica.ru': 1,
#  'spatium.ru': 1,
#  'acslog.ru': 1,
#  'loud.com': 1,
#  '10mail.org': 2,
#  'aviaberkut.ru': 1,
#  'mhshop.ru': 1,
#  'sktuote.ru': 1,
#  'modulbank.ru': 1,
#  'walla.co.il': 3,
#  'list.ru1': 2,
#  'test.kg': 1,
#  'p33.orgш': 1,
#  'yndex.ru': 6,
#  'yabloki19.ru': 1,
#  'sphere-ic.ru': 1,
#  'space307.com': 2,
#  'digitalizm.com': 1,
#  'osgrm.ru': 1,
#  'iprospect.ru': 1,
#  'kapitonov.org': 1,
#  'mskh.am': 2,
#  'carprice.ru': 1,
#  'retal.ru': 1,
#  'phoenix-llc.ru': 1,
#  'fizmat.kz': 1,
#  'gmaila.com': 1,
#  'вгд.ру': 1,
#  'erghg.ry': 1,
#  'ru.ibm.com': 1,
#  'nordavia.ru': 5,
#  'metaclay.com': 1,
#  'i-kompas.ru': 1,
#  'jugru.org': 1,
#  'ostrovok.ru': 2,
#  'ryy.ru': 1,
#  'asdasd.ru': 2,
#  'rr.rr': 1,
#  'pepsico.com': 2,
#  'bougakov.com': 1,
#  'inbow.ru': 1,
#  'kidzania.ru': 1,
#  'arview.pro': 1,
#  'hotmail.fr': 2,
#  'belugagroup.ru': 2,
#  'azurgames.com': 1,
#  'beeline.ru': 1,
#  'online.ua': 1,
#  'skyeng.com': 2,
#  'outliik.com': 1,
#  'havi.com': 2,
#  'mgppu.ru': 1,
#  'lis.ru': 1,
#  'erg.kz': 2,
#  'ub.edu': 1,
#  'zvezdnaya.ru': 1,
#  'runex.ru': 1,
#  'ru.knightfrank.com': 1,
#  'idealscorp.com': 1,
#  'outlook.ru': 1,
#  'ynade.ru': 1,
#  'askonalife.ru': 1,
#  'forafarm.ru': 1,
#  'divakovdance.ru': 1,
#  'tbenergo.ru': 1,
#  'tulatochmash.ru': 1,
#  'henkel.com': 4,
#  'valeria.com': 1,
#  'gmail.kg': 1,
#  'huhtamaki.com': 1,
#  'renol.ru': 1,
#  'gaimal.con': 1,
#  'certit.ru': 1,
#  'institute-bm.com': 1,
#  'qq.qw': 1,
#  'virbac.me': 1,
#  'priberi.ru': 1,
#  'redmond.company': 1,
#  'azan.ru': 1,
#  'sdfjhs.ru': 1,
#  'gazprom-neft.ru': 8,
#  'bayaderagroup.com': 1,
#  'imbox.ru': 3,
#  'pokrovskiy.me': 1,
#  '126.com': 1,
#  'horsgroup.com': 1,
#  'outluk.ru': 1,
#  'lppsa.com': 3,
#  'gmail.cim': 2,
#  'yandex.tu': 1,
#  '1mail.ru': 3,
#  'mail.eu': 1,
#  'yahoo.fr': 4,
#  'ancor.ru': 1,
#  'tn.ru': 5,
#  '3003mail.ru': 1,
#  'qq.hs': 1,
#  'angaratech.ru': 2,
#  'primezone.ru': 1,
#  'tmnovo.ru': 1,
#  'compel.ru': 1,
#  'baranchuk.com': 2,
#  'helenbloom.ru': 1,
#  'shire.com': 1,
#  'gmsil.com': 5,
#  'tk73.ru': 1,
#  'skyeng1.ru': 1,
#  'yahoo.ro': 1,
#  'hiq.ru': 1,
#  'pirelli.com': 2,
#  'monopoly.su': 1,
#  'iclound.com': 1,
#  'orange.fr': 1,
#  'it-kurs.com': 1,
#  'gmli.com': 1,
#  'ua.fm': 2,
#  'growtalent.ru': 1,
#  'inboz.ru': 1,
#  'inbox.ru2': 3,
#  'bl.ru': 2,
#  'factorymarket.com': 1,
#  'pernod-ricard.com': 1,
#  'maukl.ru': 1,
#  'gmail.kom': 1,
#  'gmaik.com': 1,
#  'urfu.me': 2,
#  'ays-club.ru': 1,
#  'tra.ai': 1,
#  'dngroup.ru': 1,
#  'drugnevest.ru': 1,
#  'sm-komandor.ru': 1,
#  'okc11.ru': 1,
#  '1c.com': 3,
#  'incotex.ru': 1,
#  'gnail.com': 3,
#  'devnull.facebook.com': 15,
#  'vestar.net': 1,
#  'ralf.ru': 1,
#  'avi-pro.ru': 1,
#  'skyeng.ry': 1,
#  'ru.pvmgrp.com': 2,
#  'yahoo.com.br': 1,
#  'hotmail.de': 2,
#  'tester.ru': 1,
#  'tass.ru': 1,
#  'test.email255': 1,
#  'bodnar.ru': 1,
#  'hotmail.es': 8,
#  'bbr.ru': 1,
#  'maii.ru': 2,
#  'forbes.ru': 1,
#  'vumk.com': 1,
#  'bhu.kg': 1,
#  'sdtfhg.ru': 1,
#  'picaso-3d.ru': 1,
#  'english-smart.ru': 1,
#  'bmw.com': 1,
#  'rjejdj.dde': 1,
#  'stalcom.com': 1,
#  'yandrx.ru': 2,
#  'cashwagon.com': 1,
#  'kzn.beeline.ru': 1,
#  'icloud.mail': 1,
#  'alpari.org': 3,
#  'infovizion.ru': 1,
#  'method-agency.ru': 1,
#  'br.ru': 1,
#  '72.ru': 1,
#  'vyatplita.ru': 1,
#  'qw.rp': 1,
#  '2009.com': 1,
#  'yadex.ru': 4,
#  'dasglobal.ru': 1,
#  'qmail.ru': 1,
#  'dial-parts.ru': 1,
#  'egis.ru': 3,
#  'test.tt': 1,
#  'part-iskra.org': 1,
#  'ezweb.ne.jp': 1,
#  'amrest.eu': 2,
#  'live.co.uk': 2,
#  'ikea.com': 7,
#  'urengoy.ru': 1,
#  'hotmail.it': 2,
#  'niiegp.ru': 1,
#  'wmkc.ru': 1,
#  'school1465.ru': 1,
#  'ovbport.ru': 1,
#  'test.qq': 1,
#  'kbexpert.ru': 1,
#  'artpaints.ru': 2,
#  'askona.ru': 2,
#  'dell.com': 1,
#  'yesonline.su': 1,
#  'goods.ru': 1,
#  'test.email681': 1,
#  'electronicalabel.ru': 1,
#  'sdventures.com': 3,
#  'ds032.com': 1,
#  'petrovich.ru': 1,
#  'kokoskeria.com': 1,
#  '139.com': 1,
#  'mama.ru': 1,
#  'ihoo.com': 1,
#  'list.ruu': 1,
#  'klkf.ru': 1,
#  'fadente.es': 1,
#  'mjr.ru': 1,
#  'mail.ru0': 1,
#  '156.com': 1,
#  'asap.msk.ru': 1,
#  'mgimo.ru': 1,
#  'vseinstrumenti.ru': 1,
#  'shaw.ca': 1,
#  'xandex.ru': 1,
#  'nissan.ru': 1,
#  'chumov.ru': 1,
#  'delvedeeper.com': 1,
#  'list.com': 1,
#  'ghsddsg.dsg': 1,
#  'indatalabs.com': 2,
#  'mail.ru123': 3,
#  'gmal.ru': 1,
#  'some.ru': 1,
#  'gmail.caws': 1,
#  'redmadrobot.com': 1,
#  '279.ru': 1,
#  'knaufinsulation.com': 1,
#  'test.dfg': 1,
#  'boardriders.com': 2,
#  'price-media.ru': 1,
#  'lmail.com': 1,
#  'group2901.com': 1,
#  'iclaud.com': 1,
#  'parity.digital': 1,
#  'propellerads.net': 1,
#  'molodost.bz': 1,
#  'nail.ru': 4,
#  'eutelsat.com': 1,
#  'fgdfhgfd.ru': 1,
#  'ktkd.ru': 1,
#  'iclod.com': 2,
#  'dent.md': 1,
#  'moscow-leningradskaya.ru': 1,
#  'trendufa.ru': 1,
#  'calltouch.net': 1,
#  'veb-leasing.ru': 1,
#  'icoud.com': 2,
#  'school777.ru': 1,
#  '2gmail.com': 1,
#  'sveza.com': 1,
#  'ves-media.com': 1,
#  'imail.ru': 1,
#  'ru.ey.com': 1,
#  'o3enzyme.com': 1,
#  'geropharm.com': 1,
#  'burgerking.ru': 4,
#  'meil.ru': 2,
#  'tdaero.ru': 1,
#  'interlingua.edu.ru': 1,
#  'globalprinting.ru': 1,
#  'skibinski.nsk.ru': 1,
#  'vichy.ru': 1,
#  '98gmail.com': 1,
#  'isla.vc': 1,
#  'yahoo.co.jp': 1,
#  'facebook.com': 2,
#  'hansa.ru': 1,
#  'ottoruss.ru': 1,
#  'atomproekt.com': 1,
#  'heros3.com': 2,
#  'dwteam.ru': 1,
#  'libertyrus.ru': 1,
#  'azyfuy.ry': 1,
#  'junglejobs.ru': 1,
#  'mil.ru': 4,
#  'airastana.com': 4,
#  'geosplit.ru': 1,
#  '2gis.ru': 1,
#  'wfff.qv': 1,
#  'qiwi.com': 4,
#  'ridzel.ru': 1,
#  'zimail.ru': 1,
#  'jdecoffee.com': 1,
#  'bshg.com': 1,
#  'afitness.ru': 1,
#  'fly-tech.ru': 1,
#  'awesta.ru': 1,
#  'jj.gh': 1,
#  'ua.ru': 1,
#  'russianpost.ru': 1,
#  'nrservice.ru': 1,
#  'gre.la': 1,
#  'yahoo.ca': 2,
#  'merkatorgroup.ru': 1,
#  'k.ru': 1,
#  'sogaz.ru': 1,
#  'rambler.com': 1,
#  'vingrad.ru': 1,
#  'ssscredit.ru': 1,
#  'olympus-europa.com': 1,
#  'unisender.com': 1,
#  'gymn1sam.ru': 1,
#  'trapezatour.md': 1,
#  'pochtamt.ru': 1,
#  'itechart-group.com': 1,
#  'nipt.ru': 1,
#  'vizart.tv': 1,
#  'airpush.com': 1,
#  'ferronordic.com': 1,
#  'globus.ru': 1,
#  'wemakefab.ru': 1,
#  'smartscribe.biz': 1,
#  'familyiv.com': 1,
#  'drgdfhh.ru': 1,
#  'effem.com': 1,
#  'mail.con': 1,
#  'pro1.ru': 1,
#  'zhaikmunai.kz': 2,
#  'im-agency.ru': 1,
#  'pk.ru': 1,
#  'maill.ru': 3,
#  'mmm.ru': 1,
#  'yandex.rux': 1,
#  'servier.com': 1,
#  'revolut.com': 2,
#  'maiil.ru': 1,
#  'vezet.ru': 1,
#  'fdlgkj.ruu': 1,
#  'dydysbbd.ru': 1,
#  'kharkov.ua': 1,
#  'ehl.ch': 1,
#  'il.com': 2,
#  'irisdigital.ru': 1,
#  'yanddx.ru': 1,
#  'gmaie.com': 1,
#  'gmale.com': 1,
#  'nationalropeways.ru': 1,
#  'vmani.com': 2,
#  'lobsterfilm.com': 1,
#  'wer.ru': 2,
#  'gotar.ru': 1,
#  'wp.pl': 1,
#  'itc-logistic.ru': 1,
#  'eldorado.ru': 1,
#  'el-com.ru': 1,
#  'elmi.ru': 1,
#  'mail2k.ru': 1,
#  'ge.com': 2,
#  'gmail.coam': 1,
#  'tsum.ru': 2,
#  'ekoniva.com': 2,
#  'festial.es': 1,
#  'yandex.ru1': 8,
#  'axzon.eu': 1,
#  'mustangtk.ru': 1,
#  'kru.ru': 1,
#  'aeroflot.ru': 1,
#  'maaaail.rru': 1,
#  'jet.msk': 1,
#  'slyeng.ru': 1,
#  'skyengo.ru': 1,
#  'mtglobal.ru': 1,
#  'surw.ru': 1,
#  'ser.ty': 1,
#  'molinator111.ru': 1,
#  'sch2009.net': 1,
#  'arbtr.legal': 1,
#  'mail.edu': 1,
#  'artox-media.ru': 1,
#  'alloka.ru': 1,
#  'fun-box.ru': 1,
#  'lexkeller.ru': 1,
#  'avrp.ru': 1,
#  'solgarvitamin.ru': 1,
#  'sdfsdf.com': 1,
#  'ghrh.gh': 1,
#  'ru.nestle.com': 3,
#  'corning.com': 1,
#  'cosmostone.ru': 1,
#  'googi.com': 1,
#  'mindbox.ru': 2,
#  'lge.com': 2,
#  'crm.st': 1,
#  'infosec.ru': 1,
#  'chelcom.ru': 1,
#  'loreal.com': 2,
#  'koskogoup.ru': 1,
#  'issart.com': 1,
#  'hotmail.gr1': 1,
#  'yauzacabel.ru': 1,
#  'tumo.org': 4,
#  'frtk.ru': 1,
#  'gm32ail.com': 1,
#  'lksdjfl.ru': 1,
#  'yasgku.org': 1,
#  'yangex.ru': 2,
#  'newmail.ru': 1,
#  'rusimport.ru': 1,
#  'id-logistics.com': 2,
#  'pflb.ru': 1,
#  'playgendary.com': 2,
#  '74.ru': 2,
#  'resenergo.ru': 1,
#  'missionfoods.com': 1,
#  'polyusgold.com': 1,
#  'alice.it': 1,
#  'skyeng.co': 3,
#  'obi.ru': 1,
#  'svel.ru': 2,
#  'thomasint.ru': 1,
#  'richemont.com': 1,
#  'yandex,ru': 1,
#  'testovaya.ru': 1,
#  'misslo.com': 1,
#  'liftmarketing.ru': 1,
#  'poliada.pro': 1,
#  'bory.ru': 1,
#  'mailb.com': 2,
#  'testqwerty.com': 1,
#  'itup.tech': 1,
#  'skolkovo.ru': 3,
#  'iclud.com': 1,
#  'sovacapital.com': 1,
#  'roderk.ru': 1,
#  'sovcombank.ru': 1,
#  'wikrgroup.com': 1,
#  'therubin.ru': 1,
#  'dev.com': 6,
#  'kak.ru': 1,
#  'bek.ru': 1,
#  'gmaol.com': 2,
#  'uchinovoe.ru': 1,
#  'vkcode.ru': 1,
#  'pma.su': 1,
#  'hotmai.it': 1,
#  'alfa-transit.com': 1,
#  'tatar.ru': 2,
#  '02gmail.ru': 1,
#  'papakaya.com': 1,
#  'smr.bcs.ru': 1,
#  'cushwake.com': 1,
#  'lika-tur.ru': 1,
#  'velesstroy.com': 1,
#  'ail.com': 1,
#  'devnullmail.com': 3,
#  'goldensim.ru': 1,
#  'gmail.comsa': 1,
#  'geops.ru': 1,
#  'testmail.ru': 2,
#  'yandeх.ru': 1,
#  'guerillamail.com': 2,
#  'perfobur.com': 1,
#  'kostomuksha.ru': 1,
#  'dataduck.com': 1,
#  'qq.hr': 1,
#  'tochka.com': 1,
#  'mail.fr': 1,
#  'konstanti.ru': 1,
#  'skyeng.rd': 1,
#  'areva.com': 1,
#  '608gmail.com': 1,
#  'sibir.rt.ru': 1,
#  'fesco.com': 2,
#  'onego.ru': 2,
#  'litsey2.ru': 1,
#  'uchitelnik.ru': 1,
#  'beloyarka.com': 1,
#  'louder.ru': 1,
#  'email.it': 1,
#  'gmaii.com': 1,
#  'jilfond.ru': 1,
#  'bb.bb': 1,
#  'gmfdsfa3.com': 1,
#  'yanex.ru': 4,
#  'aall.ru': 1,
#  'mailsource.info': 1,
#  'ls.ru': 1,
#  'baskir.ru': 1,
#  'teux.ru': 1,
#  '11gmail.com': 2,
#  'gmaill.com': 4,
#  'bk.during': 1,
#  'inbox.ru9': 1,
#  'emil.com': 1,
#  'difff.ru': 1,
#  'fleetcor.ru': 1,
#  'verra.ru': 1,
#  'gimail.com': 1,
#  'posterscope.ru': 1,
#  'fjskfd.ru': 1,
#  'fgh.ru': 1,
#  'morois.ru': 1,
#  'maiinator.com': 1,
#  'slb.com': 1,
#  'inn.ru': 4,
#  'accenture.com': 2,
#  'licey21.su': 1,
#  'alov.me': 1,
#  'tvel.ru': 1,
#  'uker.net': 1,
#  'dfgdfgdfg.ru': 1,
#  'qw.mi': 1,
#  'ovanesov.ru': 1,
#  'egor.im': 1,
#  ...}

# %% [markdown]
# # 🎉🎉🎉 Поздравляем, ты великолепен!
